# %%
pip install git+https://github.com/openai/whisper.git

# %%
pip install pytube pandas

# %%
import pytube as pt
import whisper
import pandas as pd
import os
import re

# %%
model = whisper.load_model("base", device="cuda")

# %%
playlist_url = "https://youtube.com/playlist?list=PL4A2F331EE86DCC22&si=wHXUk-zrjM2IalVh"
num_videos = 90
output_folder = "audio"

# %%
playlist = pt.Playlist(playlist_url)
video_data = []
missing_videos = 0

for i, url in enumerate(playlist.video_urls[:num_videos], start=1):
    print(url)
    
    try:
        # Fetch the YouTube video
        yt = pt.YouTube(url)
        
        # Filter and select the first audio stream
        stream = yt.streams.filter(only_audio=True).first()
        
        # Define the output file name
        output_file = os.path.join(output_folder, f"{i}_tagesschau.mp3")
        
        # Download the audio stream
        stream.download(filename=output_file)
        
        # Append the video data to the list
        video_data.append({
            "ID": i,
            "url": url,
            "path": output_file
        })
    
    except pt.exceptions.AgeRestrictedError:
        print(f"Video {url} is age restricted and will be skipped.")
        missing_videos += 1
    except Exception as e:
        print(f"An error occurred with video {url}: {e}")
        missing_videos += 1
# Out:
# https://www.youtube.com/watch?v=pWuYkzRypf8
# https://www.youtube.com/watch?v=MAmyhxJoZFM
# https://www.youtube.com/watch?v=AVqitc2vJ0c
# https://www.youtube.com/watch?v=Nmwe8gXfu1c
# https://www.youtube.com/watch?v=-okNLhbCcHc
# https://www.youtube.com/watch?v=SSOlNLbcA70
# https://www.youtube.com/watch?v=0CL0PHE56dg
# https://www.youtube.com/watch?v=bGv-H3Xdinw
# https://www.youtube.com/watch?v=IQz1ZNV6ltg
# https://www.youtube.com/watch?v=QS0Kq-lZSk4
# https://www.youtube.com/watch?v=yFXBxgYKhJ4
# https://www.youtube.com/watch?v=M6VL8HX0nY0
# https://www.youtube.com/watch?v=IxGgNCKvCaM
# https://www.youtube.com/watch?v=ZnDh-iDwQFM
# https://www.youtube.com/watch?v=4js2dhOsYx4
# https://www.youtube.com/watch?v=iOZ5l7EJyjY
# https://www.youtube.com/watch?v=--jtZ8NtFWU
# https://www.youtube.com/watch?v=aD5Qy57G2EI
# https://www.youtube.com/watch?v=NVUe7dVy9Zc
# https://www.youtube.com/watch?v=96kImrA7Iaw
# https://www.youtube.com/watch?v=nOl8wPalJZM
# https://www.youtube.com/watch?v=hm7zAxgfAgE
# https://www.youtube.com/watch?v=x9iE3MsXmP8
# https://www.youtube.com/watch?v=-2wbWAXJGAw
# https://www.youtube.com/watch?v=oHN3ikV2bHE
# https://www.youtube.com/watch?v=cULqnw6FxmM
# https://www.youtube.com/watch?v=fo87GE1g8vU
# https://www.youtube.com/watch?v=b6Cl_sz0P20
# https://www.youtube.com/watch?v=_qpPpu5EE0c
# https://www.youtube.com/watch?v=lzLJwN1NWag
# https://www.youtube.com/watch?v=QcnNH-y_fLo
# https://www.youtube.com/watch?v=M1OExzOSIrI
# https://www.youtube.com/watch?v=7vy3hPLlWmY
# https://www.youtube.com/watch?v=RC544PBhxnA
# https://www.youtube.com/watch?v=X-pePBQ-EBg
# https://www.youtube.com/watch?v=gtE7TGjaO5s
# https://www.youtube.com/watch?v=woVzg24EruM
# https://www.youtube.com/watch?v=SnfHTSTVLcw
# https://www.youtube.com/watch?v=Y3OFdFCIqPo
# https://www.youtube.com/watch?v=PzLOH5hh7qw

# %%
df = pd.DataFrame(video_data, columns=["ID", "url", "path"])

# %%
# Now get the transcription via whisper
df['text'] = ""

for index, row in df.iterrows():
    try:
        result = model.transcribe(row['path'])
        df.at[index, 'text'] = result['text']
    except Exception as e:
        print(f"An error occurred while transcribing {row['path']}: {e}")

# %%
def get_video_title(url):
    try:
        yt = pt.YouTube(url)
        return yt.title
    except Exception as e:
        return str(e)

def extract_date(title):
    date_pattern = re.compile(r'\b\d{1,2}\.\d{1,2}\.\d{2,4}\b')
    match = date_pattern.search(title)
    return match.group(0) if match else None

def convert_date(date_str):
    for fmt in ('%d.%m.%Y', '%d.%m.%y'):
        try:
            return pd.to_datetime(date_str, format=fmt)
        except ValueError:
            continue
    return None

# %%
df['title'] = df['url'].apply(get_video_title)
df['date'] = df['title'].apply(extract_date)
df['date'] = df['date'].apply(convert_date)

df.head()
# Out:
#    ID                                          url                    path  \
# 0   1  https://www.youtube.com/watch?v=pWuYkzRypf8  audio/1_tagesschau.mp3
# 1   2  https://www.youtube.com/watch?v=MAmyhxJoZFM  audio/2_tagesschau.mp3
# 2   3  https://www.youtube.com/watch?v=AVqitc2vJ0c  audio/3_tagesschau.mp3
# 3   4  https://www.youtube.com/watch?v=Nmwe8gXfu1c  audio/4_tagesschau.mp3
# 4   5  https://www.youtube.com/watch?v=-okNLhbCcHc  audio/5_tagesschau.mp3
#
#                                                 text  \
# 0   Hier ist das erste deutsche Fernsehen mit der...
# 1   Hier ist das erste deutsche Fernsehen mit der...
# 2   Hier ist das erste deutsche Fernsehen mit der...
# 3   Hier ist das erste deutsche Fernsehen mit der...
# 4   Hier ist das erste deutsche Fernsehen mit der...
#
#                               title       date
# 0  tagesschau 20:00 Uhr, 25.06.2024 2024-06-25
# 1  tagesschau 20:00 Uhr, 24.06.2024 2024-06-24
# 2  tagesschau 20:00 Uhr, 23.06.2024 2024-06-23
# 3  tagesschau 20:00 Uhr, 22.06.2024 2024-06-22
# 4  tagesschau 20:00 Uhr, 20.06.2024 2024-06-20

# %%
df.to_csv("data/data.csv", index=False)
